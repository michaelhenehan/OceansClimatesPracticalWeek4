# %%
# If you've done any work on Python as part of your course so far, the chances are you've 
# already used Numpy and MatPlotLib. In case you haven't, or in case you're working 
# virtually on MyBinder, you can install the packages that are needed for this model code 
# to work, you can use this command. 
# Uncomment your preferred method for downloading and organising packages

pip install numpy matplotlib pandas
#conda install -c conda-forge numpy matplotlib pandas

# %%
# Carbon cycle box model for undergraduate and masters students - Oceans and Climate
# Uses a simple forwards Euler method 
# Based on the schematic of Ciais et al. (2013, IPCC) and Walker and Kasting (1992, Global and Planetary Change) 
# Compiled in MATLAB by Lewis Alcott (lewis.alcott@bristol.ac.uk) and converted to Python by Michael Henehan (Michael.Henehan@bristol.ac.uk)

# When Python sees the '#' sign it skips to the next line without
# reading any of the text. The text is refered to as 'comments' and are notes to the 
# human user explaining the function of the code..
# Good code has lots of comments!! If you use this as the starting material to build or design your own model, then be sure to add plenty of comments to explain what you've done! 

# importing packages that are needed
import numpy as np 
import matplotlib.pyplot as plt 
import pandas as pd

# ----------------------------- # Model setup # ----------------------------- 
nsteps = 2600 # sets the number of model steps
dt = 0.1 # sets the timestep size, in years

# %%
# Preallocate arrays - this makes empty arrays to hold the model results (this speeds up the code, 
# because we now just have to change the values instead of making a new array each timestep)

Atmospheric_CO2 = np.full(nsteps, np.nan) 
Atmospheric_pCO2 = np.full(nsteps, np.nan) 
Surface_Ocean_DIC = np.full(nsteps, np.nan) 
Deep_Ocean_DIC = np.full(nsteps, np.nan) 
Ocean_Biota = np.full(nsteps, np.nan) 
Terrestrial_Biota = np.full(nsteps, np.nan) 
Soil = np.full(nsteps, np.nan) 
t = np.full(nsteps, np.nan) 
pH = np.full(nsteps, np.nan) 
T_surf = np.full(nsteps, np.nan)

# %%
# Initial conditions - Sets the starting values of the model reservoirs
# Values are all in Pg C, and most are simplified/converted from Walker and Kasting (1992)
# Note, these are meant to represent pre-industrial reservoirs
Atmospheric_CO2[0] = 589 
Surface_Ocean_DIC[0] = 900 
Deep_Ocean_DIC[0] = 37100 
Ocean_Biota[0] = 3 
Terrestrial_Biota[0] = 550 
Soil[0] = 1500 
t[0] = 1750 # sets the start year for the model to 1750 CE

# %%
# ----------------------------- # Model loop # ----------------------------- 
for n in range(nsteps): 
    # First will calculate model parameters and processes at this timestep
    # All values are calculated in GtC per year
    # Global parameters 
    Atmospheric_pCO2[n] = Atmospheric_CO2[n] / 2.124   # A simplified formula used to approximate the partial pressure of carbon dioxide from the total CO2 reservoir - 2.124 Pg C per ppm CO2 
    Climate_Sensitivity = 3 # Assumes a climate sensitivity of 3˚/doubling of CO2
    Global_Temperature_Change = Climate_Sensitivity * np.log(Atmospheric_pCO2[n] / 280) / np.log(2)
    # Terrestrial parameters 
    Resp_T_Sensitivity = 0.01
    # Terrestrial processes 
    F_Terrestrial_Photosynthesis = 110 * (Atmospheric_pCO2[n] / 280)**0.5 
    F_Terrestrial_Biota_Respiration = 0.5 * F_Terrestrial_Photosynthesis 
    F_Soil_Respiration = 54 * (Soil[n] / Soil[0]) * (1 + Resp_T_Sensitivity * Global_Temperature_Change) 
    F_Litter_Fall = 55 * (Terrestrial_Biota[n] / Terrestrial_Biota[0]) 
    F_Runoff = 1 * (Soil[n] / Soil[0])
    # Volcanic flux 
    F_Volcanic_CO2 = 0.1
    # Surface ocean processes 
    F_Ocean_Photosynthesis = 50 
    F_Ocean_Respiration = 37 
    F_Downwelling = 90 * (Surface_Ocean_DIC[n] / Surface_Ocean_DIC[0])
    # Deep ocean processes 
    F_Remineralization = 13 
    F_Upwelling = 103 * (Deep_Ocean_DIC[n] / Deep_Ocean_DIC[0]) 
    F_Burial = 0.1
    # Carbonate chemistry 
    Surface_Volume = 3.63e16 
    Surface_C_Concentration = Surface_Ocean_DIC[n] * 8.33e13 / Surface_Volume 
    Surface_Alk = 2.24265 
    T_surf[n] = 288 + Global_Temperature_Change # in Kelvin, assumes a starting temperature of 14.85˚C
    # The following K constants are for the carbonate system and are greatly simplified 
    # for ease of calculation - formulation comes from Walker and Kasting, which in turned followed Broecker and Peng (1982)
    k_1 = 8.73e-7 # This is the K1 constant given for 20˚C, 1 atm by Broecker and Peng (1982, page 151)
    k_ao = 0.278 
    k_carb = 0.000575 + 0.000006 * (T_surf[n] - 278) # Kcarb is K2/K1, in Walker and Kasting
    KCO2 = 0.035 + 0.0019 * (T_surf[n] - 278) #KCO2= K2/(alphaK1*280µatm), again as defined in Walker and Kasting

    # Carbonate speciation - note this is all fairly simplified
    term = Surface_C_Concentration**2 - Surface_Alk * (2 * Surface_C_Concentration - Surface_Alk) * (1 - 4 * k_carb) 
    Ocean_HCO3 = (Surface_C_Concentration - np.sqrt(term)) / (1 - 4 * k_carb) 
    Ocean_CO3 = (Surface_Alk - Ocean_HCO3) / 2 
    Ocean_H = k_carb * k_1 * Ocean_HCO3 / Ocean_CO3 
    pH[n] = -np.log10(Ocean_H)

    # Air–sea exchange 
    Ocean_pCO2 = 280 * KCO2 * (Ocean_HCO3**2 / Ocean_CO3) 
    F_CO2_Exchange = k_ao * (Atmospheric_pCO2[n] - Ocean_pCO2)
    
    # Update reservoirs (Euler forward) by adding and subtracting sources and sinks
    # We multiply by dt because each source or sink process is defined in Gt of carbon per year and dt is your time in years
    # On the final model step (n = steps) we do not calculate the future reservoir sizes, hence the 'if' statement
    if n < nsteps - 1: 
        Atmospheric_CO2[n+1] = Atmospheric_CO2[n] + ( F_Soil_Respiration + F_Terrestrial_Biota_Respiration + F_Volcanic_CO2 - F_CO2_Exchange - F_Terrestrial_Photosynthesis ) * dt 
        Surface_Ocean_DIC[n+1] = Surface_Ocean_DIC[n] + ( F_Ocean_Respiration + F_Upwelling + F_Runoff + F_CO2_Exchange - F_Downwelling - F_Ocean_Photosynthesis ) * dt 
        Deep_Ocean_DIC[n+1] = Deep_Ocean_DIC[n] + ( F_Downwelling + F_Remineralization - F_Upwelling - F_Burial ) * dt 
        Ocean_Biota[n+1] = Ocean_Biota[n] + ( F_Ocean_Photosynthesis - F_Ocean_Respiration - F_Remineralization ) * dt 
        Terrestrial_Biota[n+1] = Terrestrial_Biota[n] + ( F_Terrestrial_Photosynthesis - F_Terrestrial_Biota_Respiration - F_Litter_Fall ) * dt 
        Soil[n+1] = Soil[n] + ( F_Litter_Fall - F_Soil_Respiration - F_Runoff ) * dt 
        t[n+1] = t[n] + dt

# %%
# Now the model has finished we can plot the results
# The following code makes a new figure with 6 subplots that show the
# variations in the major reservoirs (although pCO2 is used instead of CO2 
# in Gt as it's more intuitive)


# ----------------------------- # Plotting # -----------------------------

fig, axs = plt.subplots(2, 3, figsize=(12, 8)) 
axs[0, 0].plot(t, Atmospheric_pCO2)
axs[0, 0].set_xlabel("Year") 
axs[0, 0].set_ylabel("Atmospheric pCO₂")

axs[0, 1].plot(t, Surface_Ocean_DIC) 
axs[0, 1].set_xlabel("Year") 
axs[0, 1].set_ylabel("Surface Ocean DIC")

axs[0, 2].plot(t, Deep_Ocean_DIC) 
axs[0, 2].set_xlabel("Year") 
axs[0, 2].set_ylabel("Deep Ocean DIC")

axs[1, 0].plot(t, Ocean_Biota) 
axs[1, 0].set_xlabel("Year") 
axs[1, 0].set_ylabel("Ocean Biota Carbon") 

axs[1, 1].plot(t, Terrestrial_Biota) 
axs[1, 1].set_xlabel("Year") 
axs[1, 1].set_ylabel("Terrestrial Biota Carbon")

axs[1, 2].plot(t, Soil) 
axs[1, 2].set_xlabel("Year") 
axs[1, 2].set_ylabel("Soil Carbon")

plt.tight_layout() 
plt.show()

# %%
## PART 3: Simulating Anthropogenic CO2 release

# Read in your emissions scenario, which you should have downloaded to the same directory as your Python Notebook. 
emissions= pd.read_csv('Anthro_CO2_Input.csv', header=0, sep=",")

# %%
# You'll need to interpolate between these data in decade steps in order to get the 
# values at 0.1 year resolution, which is the resolution the model was set to run out. 
# You already set the model to do 260 years at 0.1 year steps ('dt'). 

time = np.full(nsteps, np.nan) 
Ffuelflux = np.full(nsteps, np.nan)

for n in range(nsteps): 
    time[n]=1750+(n*dt)
    Ffuelflux[n]=np.interp(time[n],emissions.Decade,emissions.Ffuel_release_GtCperyear)

#print(time, Ffuelflux)

# Here you can plot your interpolated data aside the raw data to double check you did the interpolation right  
fig, axs = plt.subplots(1, 2, figsize=(12, 8)) 
axs[0].plot(time, Ffuelflux)
axs[0].set_xlabel("Year") 
axs[0].set_ylabel("Interpolated Fossil Fuel Flux")

axs[1].plot(emissions.Decade, emissions.Ffuel_release_GtCperyear) 
axs[1].set_xlabel("Decade") 
axs[1].set_ylabel("Decadal Fossil Fuel Flux")

plt.tight_layout() 
plt.show()

# %%
# Now modelling your anthropogenic CO2 input
# Note the anthropogenic input should be added to the Atmospheric reservoir


# ----------------------------- # Model loop # ----------------------------- 
for n in range(nsteps): 
    # First will calculate model parameters and processes at this timestep
    # All values are calculated in GtC per year
    # Global parameters 
    Atmospheric_pCO2[n] = Atmospheric_CO2[n] / 2.124   # A simplified formula used to approximate the partial pressure of carbon dioxide from the total CO2 reservoir - 2.124 Pg C per ppm CO2 
    Climate_Sensitivity = 3 # Assumes a climate sensitivity of 3˚/doubling of CO2
    Global_Temperature_Change = Climate_Sensitivity * np.log(Atmospheric_pCO2[n] / 280) / np.log(2)
    # Terrestrial parameters 
    Resp_T_Sensitivity = 0.01
    # Terrestrial processes 
    F_Terrestrial_Photosynthesis = 110 * (Atmospheric_pCO2[n] / 280)**0.5 
    F_Terrestrial_Biota_Respiration = 0.5 * F_Terrestrial_Photosynthesis 
    F_Soil_Respiration = 54 * (Soil[n] / Soil[0]) * (1 + Resp_T_Sensitivity * Global_Temperature_Change) 
    F_Litter_Fall = 55 * (Terrestrial_Biota[n] / Terrestrial_Biota[0]) 
    F_Runoff = 1 * (Soil[n] / Soil[0])
    # Volcanic flux 
    F_Volcanic_CO2 = 0.1
    # Surface ocean processes 
    F_Ocean_Photosynthesis = 50 
    F_Ocean_Respiration = 37 
    F_Downwelling = 90 * (Surface_Ocean_DIC[n] / Surface_Ocean_DIC[0])
    # Deep ocean processes 
    F_Remineralization = 13 
    F_Upwelling = 103 * (Deep_Ocean_DIC[n] / Deep_Ocean_DIC[0]) 
    F_Burial = 0.1
    # Carbonate chemistry 
    Surface_Volume = 3.63e16 
    Surface_C_Concentration = Surface_Ocean_DIC[n] * 8.33e13 / Surface_Volume 
    Surface_Alk = 2.24265 # in mmol/m^-3
    T_surf[n] = 288 + Global_Temperature_Change # in Kelvin, assumes a starting temperature of 14.85˚C
    # The following K constants are for the carbonate system and are greatly simplified 
    # for ease of calculation - formulation comes from Walker and Kasting, which in turned followed Broecker and Peng (1982)
    k_1 = 8.73e-7 # This is the K1 constant given for 20˚C, 1 atm by Broecker and Peng (1982, page 151)
    k_ao = 0.278 
    k_carb = 0.000575 + 0.000006 * (T_surf[n] - 278) # Kcarb is K2/K1, in Walker and Kasting
    KCO2 = 0.035 + 0.0019 * (T_surf[n] - 278) #KCO2= K2/(alphaK1*280µatm), again as defined in Walker and Kasting

    # Carbonate speciation - note this is all fairly simplified
    term = Surface_C_Concentration**2 - Surface_Alk * (2 * Surface_C_Concentration - Surface_Alk) * (1 - 4 * k_carb) 
    Ocean_HCO3 = (Surface_C_Concentration - np.sqrt(term)) / (1 - 4 * k_carb) 
    Ocean_CO3 = (Surface_Alk - Ocean_HCO3) / 2 
    Ocean_H = k_carb * k_1 * Ocean_HCO3 / Ocean_CO3 
    pH[n] = -np.log10(Ocean_H)

    # Air–sea exchange 
    Ocean_pCO2 = 280 * KCO2 * (Ocean_HCO3**2 / Ocean_CO3) 
    F_CO2_Exchange = k_ao * (Atmospheric_pCO2[n] - Ocean_pCO2)
    
    # Update reservoirs (Euler forward) by adding and subtracting sources and sinks
    # We multiply by dt because each source or sink process is defined in Gt of carbon per year and dt is your time in years
    # On the final model step (n = steps) we do not calculate the future reservoir sizes, hence the 'if' statement
    if n < nsteps - 1: 
        Atmospheric_CO2[n+1] = Atmospheric_CO2[n] + ( F_Soil_Respiration + F_Terrestrial_Biota_Respiration + F_Volcanic_CO2 - F_CO2_Exchange - F_Terrestrial_Photosynthesis + Ffuelflux[n]) * dt 
        Surface_Ocean_DIC[n+1] = Surface_Ocean_DIC[n] + ( F_Ocean_Respiration + F_Upwelling + F_Runoff + F_CO2_Exchange - F_Downwelling - F_Ocean_Photosynthesis ) * dt 
        Deep_Ocean_DIC[n+1] = Deep_Ocean_DIC[n] + ( F_Downwelling + F_Remineralization - F_Upwelling - F_Burial ) * dt 
        Ocean_Biota[n+1] = Ocean_Biota[n] + ( F_Ocean_Photosynthesis - F_Ocean_Respiration - F_Remineralization ) * dt 
        Terrestrial_Biota[n+1] = Terrestrial_Biota[n] + ( F_Terrestrial_Photosynthesis - F_Terrestrial_Biota_Respiration - F_Litter_Fall ) * dt 
        Soil[n+1] = Soil[n] + ( F_Litter_Fall - F_Soil_Respiration - F_Runoff ) * dt 
        t[n+1] = t[n] + dt

# %%
# Now the model has finished we can plot the results
# The following code makes a new figure with 6 subplots that show the
# variations in the major reservoirs (although pCO2 is used instead of CO2 
# in Gt as it's more intuitive)


# ----------------------------- # Plotting # -----------------------------

fig, axs = plt.subplots(2, 3, figsize=(12, 8)) 
axs[0, 0].plot(t, Atmospheric_pCO2)
axs[0, 0].set_xlabel("Year") 
axs[0, 0].set_ylabel("Atmospheric pCO₂")

axs[0, 1].plot(t, Surface_Ocean_DIC) 
axs[0, 1].set_xlabel("Year") 
axs[0, 1].set_ylabel("Surface Ocean DIC")

axs[0, 2].plot(t, Deep_Ocean_DIC) 
axs[0, 2].set_xlabel("Year") 
axs[0, 2].set_ylabel("Deep Ocean DIC")

axs[1, 0].plot(t, Ocean_Biota) 
axs[1, 0].set_xlabel("Year") 
axs[1, 0].set_ylabel("Ocean Biota Carbon") 

axs[1, 1].plot(t, Terrestrial_Biota) 
axs[1, 1].set_xlabel("Year") 
axs[1, 1].set_ylabel("Terrestrial Biota Carbon")

axs[1, 2].plot(t, Soil) 
axs[1, 2].set_xlabel("Year") 
axs[1, 2].set_ylabel("Soil Carbon")

plt.tight_layout() 
plt.show()

# %% [markdown]
# Answering 3.3:
# CO2 doesn't get as high as what happened..in 2010 we were at about 389 ppm.
#
# Answering 3.4:
# Many possibilities here:
# 1. Limitations in the carbonate system calculations – Assumes all alkalinity is carbonate
# alkalinity, while the carbonate K constants have been greatly simplified. K constants
# are not responsive to temperature and there is no parameterisation of salinity, so
# carbonate system calculations are very rough. K0 has no temperature dependency.
# 2. Human activity like deforestation is also likely to have reduced the terrestrial biomass
# and also the soil C stock.
# 3. One of the fluxes out is overestimated to begin with.
# 4. There's been a change in ocean productivity or respiration maybe?
#
# If you were going to influence for example terrestrial biomass, you'd probably want
# to change F_Terrestrial_Photosynthesis. To change soil C stock, you'd probably
# want to increase F_Soil_Respiration or F_Soil_Runofficial.

# %%
# PART 4: Ocean Alkalinity Enhancement
# Alkalinity is fixed.. you'd want to adjust it so that the things that involve Alkalinity 
# are moved into the loop. 

# Preallocate arrays for things that will be affected by your change in alkalinity 
Surface_Alk = np.full(nsteps, np.nan) 
term = np.full(nsteps, np.nan) 
Ocean_HCO3 = np.full(nsteps, np.nan) 
Ocean_pCO2 = np.full(nsteps, np.nan) 
Ocean_CO3 = np.full(nsteps, np.nan) 
Ocean_H = np.full(nsteps, np.nan) 
Ocean_pCO2 = np.full(nsteps, np.nan) 
F_CO2_Exchange = np.full(nsteps, np.nan) 

# Let's try this as an alkalinity evolution
time = np.full(nsteps, np.nan) 
timespan=[1750,1750+nsteps*dt]
alkEvol=[2.24265,2.38] ## rising up to 2.4

for n in range(nsteps): 
    time[n]=1750+(n*dt)
    Surface_Alk[n]=np.interp(time[n],timespan,alkEvol)

print(Surface_Alk)
# Out:
# [2.24265    2.24270283 2.24275565 ... 2.37984152 2.37989435 2.37994717]

# %%
# Now implementing these changing things into the model


# ----------------------------- # Model loop # ----------------------------- 
for n in range(nsteps): 
    # First will calculate model parameters and processes at this timestep
    # All values are calculated in GtC per year
    # Global parameters 
    Atmospheric_pCO2[n] = Atmospheric_CO2[n] / 2.124   # A simplified formula used to approximate the partial pressure of carbon dioxide from the total CO2 reservoir - 2.124 Pg C per ppm CO2 
    Climate_Sensitivity = 3 # Assumes a climate sensitivity of 3˚/doubling of CO2
    Global_Temperature_Change = Climate_Sensitivity * np.log(Atmospheric_pCO2[n] / 280) / np.log(2)
    # Terrestrial parameters 
    Resp_T_Sensitivity = 0.01
    # Terrestrial processes 
    F_Terrestrial_Photosynthesis = 110 * (Atmospheric_pCO2[n] / 280)**0.5 
    F_Terrestrial_Biota_Respiration = 0.5 * F_Terrestrial_Photosynthesis 
    F_Soil_Respiration = 54 * (Soil[n] / Soil[0]) * (1 + Resp_T_Sensitivity * Global_Temperature_Change) 
    F_Litter_Fall = 55 * (Terrestrial_Biota[n] / Terrestrial_Biota[0]) 
    F_Runoff = 1 * (Soil[n] / Soil[0])
    # Volcanic flux 
    F_Volcanic_CO2 = 0.1
    # Surface ocean processes 
    F_Ocean_Photosynthesis = 50 
    F_Ocean_Respiration = 37 
    F_Downwelling = 90 * (Surface_Ocean_DIC[n] / Surface_Ocean_DIC[0])
    # Deep ocean processes 
    F_Remineralization = 13 
    F_Upwelling = 103 * (Deep_Ocean_DIC[n] / Deep_Ocean_DIC[0]) 
    F_Burial = 0.1
    # Carbonate chemistry 
    Surface_Volume = 3.63e16 
    Surface_C_Concentration = Surface_Ocean_DIC[n] * 8.33e13 / Surface_Volume 
    #Surface_Alk = 2.24265 # in mmol/m^-3 # this is what you've replaced with a new array
    T_surf[n] = 288 + Global_Temperature_Change # in Kelvin, assumes a starting temperature of 14.85˚C
    # The following K constants are for the carbonate system and are greatly simplified 
    # for ease of calculation - formulation comes from Walker and Kasting, which in turned followed Broecker and Peng (1982)
    k_1 = 8.73e-7 # This is the K1 constant given for 20˚C, 1 atm by Broecker and Peng (1982, page 151)
    k_ao = 0.278 
    k_carb = 0.000575 + 0.000006 * (T_surf[n] - 278) # Kcarb is K2/K1, in Walker and Kasting
    KCO2 = 0.035 + 0.0019 * (T_surf[n] - 278) #KCO2= K2/(alphaK1*280µatm), again as defined in Walker and Kasting

    # Carbonate speciation - note this is all fairly simplified
    term[n] = Surface_C_Concentration**2 - Surface_Alk[n] * (2 * Surface_C_Concentration - Surface_Alk[n]) * (1 - 4 * k_carb) 
    Ocean_HCO3[n] = (Surface_C_Concentration - np.sqrt(term[n])) / (1 - 4 * k_carb) 
    Ocean_CO3[n] = (Surface_Alk[n] - Ocean_HCO3[n]) / 2 
    Ocean_H[n] = k_carb * k_1 * Ocean_HCO3[n] / Ocean_CO3[n] 
    pH[n] = -np.log10(Ocean_H[n])

    # Air–sea exchange 
    Ocean_pCO2[n] = 280 * KCO2 * (Ocean_HCO3[n]**2 / Ocean_CO3[n]) 
    F_CO2_Exchange[n] = k_ao * (Atmospheric_pCO2[n] - Ocean_pCO2[n])
    
    # Update reservoirs (Euler forward) by adding and subtracting sources and sinks
    # We multiply by dt because each source or sink process is defined in Gt of carbon per year and dt is your time in years
    # On the final model step (n = steps) we do not calculate the future reservoir sizes, hence the 'if' statement
    if n < nsteps - 1: 
        Atmospheric_CO2[n+1] = Atmospheric_CO2[n] + ( F_Soil_Respiration + F_Terrestrial_Biota_Respiration + F_Volcanic_CO2 - F_CO2_Exchange[n] - F_Terrestrial_Photosynthesis + Ffuelflux[n]) * dt 
        Surface_Ocean_DIC[n+1] = Surface_Ocean_DIC[n] + ( F_Ocean_Respiration + F_Upwelling + F_Runoff + F_CO2_Exchange[n] - F_Downwelling - F_Ocean_Photosynthesis ) * dt 
        Deep_Ocean_DIC[n+1] = Deep_Ocean_DIC[n] + ( F_Downwelling + F_Remineralization - F_Upwelling - F_Burial ) * dt 
        Ocean_Biota[n+1] = Ocean_Biota[n] + ( F_Ocean_Photosynthesis - F_Ocean_Respiration - F_Remineralization ) * dt 
        Terrestrial_Biota[n+1] = Terrestrial_Biota[n] + ( F_Terrestrial_Photosynthesis - F_Terrestrial_Biota_Respiration - F_Litter_Fall ) * dt 
        Soil[n+1] = Soil[n] + ( F_Litter_Fall - F_Soil_Respiration - F_Runoff ) * dt 
        t[n+1] = t[n] + dt

# %%
# Now the model has finished we can plot the results
# The following code makes a new figure with 6 subplots that show the
# variations in the major reservoirs (although pCO2 is used instead of CO2 
# in Gt as it's more intuitive)


# ----------------------------- # Plotting # -----------------------------

fig, axs = plt.subplots(2, 3, figsize=(12, 8)) 
axs[0, 0].plot(t, Atmospheric_pCO2)
axs[0, 0].set_xlabel("Year") 
axs[0, 0].set_ylabel("Atmospheric pCO₂")

axs[0, 1].plot(t, Surface_Ocean_DIC) 
axs[0, 1].set_xlabel("Year") 
axs[0, 1].set_ylabel("Surface Ocean DIC")

axs[0, 2].plot(t, Deep_Ocean_DIC) 
axs[0, 2].set_xlabel("Year") 
axs[0, 2].set_ylabel("Deep Ocean DIC")

axs[1, 0].plot(t, Ocean_Biota) 
axs[1, 0].set_xlabel("Year") 
axs[1, 0].set_ylabel("Ocean Biota Carbon") 

axs[1, 1].plot(t, Terrestrial_Biota) 
axs[1, 1].set_xlabel("Year") 
axs[1, 1].set_ylabel("Terrestrial Biota Carbon")

axs[1, 2].plot(t, Soil) 
axs[1, 2].set_xlabel("Year") 
axs[1, 2].set_ylabel("Soil Carbon")

plt.tight_layout() 
plt.show()

# %% [markdown]
# Answering 4.3:
#
# So you had to increase alkalinity to 2380 µmol/L.. from 2242.65 µmol/L.. a change of 137.35 µmol/L. If the surface ocean is 3.63*10^16 L, that's 4.985*10^18 µmol or 4.985*10^12 mol of alkalinity.
#
# If all of it were CaO, which has a molar mass of 56.08 g/mol, that is 2.79559 * 10^11 kg, or 279,558,800 tonnes of CaO. Wikipedia puts yearly global production of CaO lime at between 283,000,000 and 427,000,000 tonnes, depending on how you categorise things. Of course, currently we make that in a way that releases CO2, so wouldn't be feasible unless we did it with renewable energy somehow, and captured the CO2 that comes off.. which is hard to envisage. Perhaps CaO isn't that practical.

# %%
## Part 5: Ocean fertilisation! 

## OK, now we'll look at changing CO2 with ocean fertilisation - a pseudo iron addition.. 

## Taking the CO2 input scenario, since I guess that's the world we're working in.. 
# We'll need to alter F_Ocean_Photosynthesis below. 
# Trial and error how much we need to change it to get Ice Age CO2 of 190 ppm.. 


# ----------------------------- # Model loop # ----------------------------- 
for n in range(nsteps): 
    # First will calculate model parameters and processes at this timestep
    # All values are calculated in GtC per year
    # Global parameters 
    Atmospheric_pCO2[n] = Atmospheric_CO2[n] / 2.124   # A simplified formula used to approximate the partial pressure of carbon dioxide from the total CO2 reservoir - 2.124 Pg C per ppm CO2 
    Climate_Sensitivity = 3 # Assumes a climate sensitivity of 3˚/doubling of CO2
    Global_Temperature_Change = Climate_Sensitivity * np.log(Atmospheric_pCO2[n] / 280) / np.log(2)
    # Terrestrial parameters 
    Resp_T_Sensitivity = 0.01
    # Terrestrial processes 
    F_Terrestrial_Photosynthesis = 110 * (Atmospheric_pCO2[n] / 280)**0.5 
    F_Terrestrial_Biota_Respiration = 0.5 * F_Terrestrial_Photosynthesis 
    F_Soil_Respiration = 54 * (Soil[n] / Soil[0]) * (1 + Resp_T_Sensitivity * Global_Temperature_Change) 
    F_Litter_Fall = 55 * (Terrestrial_Biota[n] / Terrestrial_Biota[0]) 
    F_Runoff = 1 * (Soil[n] / Soil[0])
    # Volcanic flux 
    F_Volcanic_CO2 = 0.1
    # Surface ocean processes 
    F_Ocean_Photosynthesis = 56 ### NB: Changed this from 50
    F_Ocean_Respiration = 37 
    F_Downwelling = 90 * (Surface_Ocean_DIC[n] / Surface_Ocean_DIC[0])
    # Deep ocean processes 
    F_Remineralization = 13 
    F_Upwelling = 103 * (Deep_Ocean_DIC[n] / Deep_Ocean_DIC[0]) 
    F_Burial = 0.1
    # Carbonate chemistry 
    Surface_Volume = 3.63e16 
    Surface_C_Concentration = Surface_Ocean_DIC[n] * 8.33e13 / Surface_Volume 
    Surface_Alk = 2.24265 # in mmol/m^-3
    T_surf[n] = 288 + Global_Temperature_Change # in Kelvin, assumes a starting temperature of 14.85˚C
    # The following K constants are for the carbonate system and are greatly simplified 
    # for ease of calculation - formulation comes from Walker and Kasting, which in turned followed Broecker and Peng (1982)
    k_1 = 8.73e-7 # This is the K1 constant given for 20˚C, 1 atm by Broecker and Peng (1982, page 151)
    k_ao = 0.278 
    k_carb = 0.000575 + 0.000006 * (T_surf[n] - 278) # Kcarb is K2/K1, in Walker and Kasting
    KCO2 = 0.035 + 0.0019 * (T_surf[n] - 278) #KCO2= K2/(alphaK1*280µatm), again as defined in Walker and Kasting

    # Carbonate speciation - note this is all fairly simplified
    term = Surface_C_Concentration**2 - Surface_Alk * (2 * Surface_C_Concentration - Surface_Alk) * (1 - 4 * k_carb) 
    Ocean_HCO3 = (Surface_C_Concentration - np.sqrt(term)) / (1 - 4 * k_carb) 
    Ocean_CO3 = (Surface_Alk - Ocean_HCO3) / 2 
    Ocean_H = k_carb * k_1 * Ocean_HCO3 / Ocean_CO3 
    pH[n] = -np.log10(Ocean_H)

    # Air–sea exchange 
    Ocean_pCO2 = 280 * KCO2 * (Ocean_HCO3**2 / Ocean_CO3) 
    F_CO2_Exchange = k_ao * (Atmospheric_pCO2[n] - Ocean_pCO2)
    
    # Update reservoirs (Euler forward) by adding and subtracting sources and sinks
    # We multiply by dt because each source or sink process is defined in Gt of carbon per year and dt is your time in years
    # On the final model step (n = steps) we do not calculate the future reservoir sizes, hence the 'if' statement
    if n < nsteps - 1: 
        Atmospheric_CO2[n+1] = Atmospheric_CO2[n] + ( F_Soil_Respiration + F_Terrestrial_Biota_Respiration + F_Volcanic_CO2 - F_CO2_Exchange - F_Terrestrial_Photosynthesis + Ffuelflux[n]) * dt 
        Surface_Ocean_DIC[n+1] = Surface_Ocean_DIC[n] + ( F_Ocean_Respiration + F_Upwelling + F_Runoff + F_CO2_Exchange - F_Downwelling - F_Ocean_Photosynthesis ) * dt 
        Deep_Ocean_DIC[n+1] = Deep_Ocean_DIC[n] + ( F_Downwelling + F_Remineralization - F_Upwelling - F_Burial ) * dt 
        Ocean_Biota[n+1] = Ocean_Biota[n] + ( F_Ocean_Photosynthesis - F_Ocean_Respiration - F_Remineralization ) * dt 
        Terrestrial_Biota[n+1] = Terrestrial_Biota[n] + ( F_Terrestrial_Photosynthesis - F_Terrestrial_Biota_Respiration - F_Litter_Fall ) * dt 
        Soil[n+1] = Soil[n] + ( F_Litter_Fall - F_Soil_Respiration - F_Runoff ) * dt 
        t[n+1] = t[n] + dt

# %%
# And now plotting the results: 

# ----------------------------- # Plotting # -----------------------------

fig, axs = plt.subplots(2, 3, figsize=(12, 8)) 
axs[0, 0].plot(t, Atmospheric_pCO2)
axs[0, 0].set_xlabel("Year") 
axs[0, 0].set_ylabel("Atmospheric pCO₂")

axs[0, 1].plot(t, Surface_Ocean_DIC) 
axs[0, 1].set_xlabel("Year") 
axs[0, 1].set_ylabel("Surface Ocean DIC")

axs[0, 2].plot(t, Deep_Ocean_DIC) 
axs[0, 2].set_xlabel("Year") 
axs[0, 2].set_ylabel("Deep Ocean DIC")

axs[1, 0].plot(t, Ocean_Biota) 
axs[1, 0].set_xlabel("Year") 
axs[1, 0].set_ylabel("Ocean Biota Carbon") 

axs[1, 1].plot(t, Terrestrial_Biota) 
axs[1, 1].set_xlabel("Year") 
axs[1, 1].set_ylabel("Terrestrial Biota Carbon")

axs[1, 2].plot(t, Soil) 
axs[1, 2].set_xlabel("Year") 
axs[1, 2].set_ylabel("Soil Carbon")

plt.tight_layout() 
plt.show()

# %%
# Answering 5.2
## In the example above we 'only' needed to change the flux from 50 Gt/yr to 56 Gt/yr...
## Note if you try something as high as 100 you run out of CO2, the model crashes and you'll get an error message. 


## Answering 5.3
## While effecting a change in Ocean Productivity of a little over 10 % doesn't sound that unfeasible.. as we 
# learnt in the lectures, there are a lot of knock on effects of doing this.. If you make that much organic matter,
# you're not going to necessarily maintain the respiration rates or burial rates.. you'll lose so much O2 that fish 
# won't survive, and maybe you'll get less efficient transport of C to the deep in faecal pellets.. 
# At the same time, though, you'll probably get so much anoxia on the seafloor that you start burying a lot more of 
# what does make it to the seafloor.. you might have got yourself an ocean anoxic event, like the ones in the 
# Cretaceous that we'll look at later in the course!
